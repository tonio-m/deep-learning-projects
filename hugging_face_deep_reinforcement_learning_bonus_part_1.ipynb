# %%
# %%shell
# git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# cd ml-agents
# pip3 install -e ./ml-agents-envs
# pip3 install -e ./ml-agents
# mkdir ./trained-envs-executables
# mkdir ./trained-envs-executables/linux
# wget "https://github.com/huggingface/Huggy/raw/main/Huggy.zip" -O ./trained-envs-executables/linux/Huggy.zip
# unzip ./trained-envs-executables/linux/Huggy.zip -d ./trained-envs-executables/linux/
# chmod -R 755 trained-envs-executables/linux/Huggy

# %%
 # %%writefile ml-agents/config/ppo/Huggy.yaml
behaviors:
  Huggy:
    trainer_type: ppo
    hyperparameters:
      batch_size: 2048
      buffer_size: 20480
      learning_rate: 0.0003
      beta: 0.005
      epsilon: 0.2
      lambd: 0.95
      num_epoch: 1 # 3
      learning_rate_schedule: linear
    network_settings:
      normalize: true
      hidden_units: 512
      num_layers: 3
      vis_encode_type: simple
    reward_signals:
      extrinsic:
        gamma: 0.995
        strength: 1.0
    checkpoint_interval: 200000
    keep_checkpoints: 15
    max_steps: 2e6
    time_horizon: 1000
    summary_freq: 50000
# Out:
# Writing ml-agents/config/ppo/Huggy.yaml

# %%
# !mlagents-learn "ml-agents/config/ppo/Huggy.yaml" --env="./trained-envs-executables/linux/Huggy/Huggy" --run-id="Huggy" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
# 2024-03-25 23:55:21.569545: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-25 23:55:21.569651: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-25 23:55:21.684108: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy" --repo-id="tonio-m/ppo-Huggy" --commit-message="Huggy"
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Huggy-199822.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
# Huggy-199822.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
# Huggy.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# checkpoint.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# Huggy-213694.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
#
# Huggy-199822.onnx:   1% 16.4k/2.27M [00:00<00:28, 79.2kB/s]
#
#
#
# Huggy-213694.pt:   0% 16.4k/13.5M [00:00<03:49, 58.8kB/s]
#
# Huggy.onnx:   1% 16.4k/2.27M [00:00<00:39, 57.0kB/s]
#
#
# checkpoint.pt:   0% 16.4k/13.5M [00:00<03:55, 57.3kB/s]
# Huggy-199822.pt:   0% 16.4k/13.5M [00:00<04:02, 55.7kB/s]
#
#
#
# Huggy-213694.pt:  40% 5.42M/13.5M [00:00<00:00, 18.0MB/s]
#
#
# checkpoint.pt:  43% 5.75M/13.5M [00:00<00:00, 18.1MB/s]
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()
